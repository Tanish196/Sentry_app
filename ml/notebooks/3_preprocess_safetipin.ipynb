# %%
import pandas as pd

# %%
INPUT_PATH = "..\\datasets\\raw\\safetipin\\safetipin_165_rows.csv"
OUTPUT_PATH = "..\\datasets\\processed\\safetipin\\safetipin_processed.csv"

df = pd.read_csv(INPUT_PATH)

# %%
df["Police_Station"] = df["Police_Station"].str.strip().str.upper()

df = df[[
    "Police_Station",
    "Safety Score",
    "Lighting",
    "Visibility",
    "Openness",
    "Security"
]]

# %%
df.to_csv(OUTPUT_PATH, index=False)
